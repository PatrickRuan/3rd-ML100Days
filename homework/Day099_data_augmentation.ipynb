# %% [markdown]
# <a href="https://colab.research.google.com/github/PatrickRuan/3rd-ML100Days/blob/master/homework/Day099_data_augmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
# %matplotlib inline
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
# 此函數會幫我們把多張影像畫成一張多宮格圖
def img_combine(img, ncols=8, size=1, path=False):
    from math import ceil
    import matplotlib.pyplot as plt
    import numpy as np
    nimg = len(img)
    nrows = int(ceil(nimg/ncols))
    fig, axes = plt.subplots(nrows=nrows, ncols=ncols, sharex=True, sharey=True, figsize=(ncols*size,nrows*size))
    if nrows == 0:
        return
    elif ncols == 1:
        for r, ax in zip(np.arange(nrows), axes):
            nth=r
            if nth < nimg:
                ax.imshow(img[nth], cmap='rainbow', vmin=0, vmax=1)
                
            ax.set_axis_off()
    elif nrows == 1:
        for c, ax in zip(np.arange(ncols), axes):
            nth=c
            if nth < nimg:
                ax.imshow(img[nth], cmap='rainbow', vmin=0, vmax=1)
            ax.set_axis_off()
    else:
        for r, row in zip(np.arange(nrows), axes):
            for c, ax in zip(np.arange(ncols), row):
                nth=r*ncols+c
                if nth < nimg:
                    ax.imshow(img[nth], cmap='rainbow', vmin=0, vmax=1)
                ax.set_axis_off()
    plt.show()

# %%
# 讀取 Cifar-10 資料集
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 11s 0us/step

# %%
# 取前 32 張圖片做視覺化
images = x_train[:32]
img_combine(images)

# %%
# 建立 ImageDataGenerator，並指定我們要做資料增強的數值範圍
data_generator = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True)

# %%
# 注意！！ ImageDataGenerator 是一個 Generator (生成器)! 對 Generator 不熟悉的同學請回到 Day098 做複習。
# 使用 .flow 後，就會對我們的影像進行增強，再 call next 取出 generator 的圖像。(shuffle=False 因為我們希望圖像的順序不要改變，方便觀察。實際訓練時預設是 shuffle=True) 
augmented_iamges = next(data_generator.flow(images, shuffle=False))
img_combine(augmented_iamges.astype("int")) # 注意在訓練時神經網路時，圖像資料必須要是 float32，但在做視覺化時要轉為 int 才能順利畫圖。所以為了畫圖才把資料轉為 int

# %%
# 因為隨機性的關係，所以一樣的圖像再經過一次 generator 後的結果不一定相同
augmented_iamges = next(data_generator.flow(images, shuffle=False))
img_combine(augmented_iamges.astype("int"))

# %% [markdown]
# ## 作業

# %% [markdown]
# 請使用 ImageDataGenerator 來進行 Cifar-10 資料集的訓練，並觀察不同的圖像增強方法是否會顯著影響訓練結果

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D,  Dropout, Flatten, Dense
from keras.utils import to_categorical
import matplotlib.pyplot as plt

# %%
batch_size = 128
epochs = 10 

(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print(x_train.shape)

x_train = x_train/255
x_test = x_test/255

y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

model = Sequential()
model.add(Conv2D(64, (3, 3),  input_shape=x_train.shape[1:], padding='same', activation='relu'))
model.add(Dropout(0.25))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(32, (3, 3), padding='same', activation='relu'))
model.add(Dropout(0.25))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3), padding='same', activation='relu'))
model.add(Dropout(0.25))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))
model.summary()

model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy'])

history = model.fit(x_train, y_train, 
                    epochs=epochs,
                    batch_size=batch_size,
                    validation_split=0.2,
                    verbose=1)
# Out:
# (50000, 32, 32, 3)
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_10 (Conv2D)           (None, 32, 32, 64)        1792
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 32, 32, 64)        0
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 16, 16, 32)        18464
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 16, 16, 32)        0
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 8, 8, 32)          9248
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 8, 8, 32)          0
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 4, 4, 32)          0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 163,402
# Trainable params: 163,402
# Non-trainable params: 0
# _________________________________________________________________
# Train on 40000 samples, validate on 10000 samples
# Epoch 1/10
# 40000/40000 [==============================] - 9s 228us/step - loss: 1.7497 - acc: 0.3560 - val_loss: 1.6244 - val_acc: 0.4786
# Epoch 2/10
# 40000/40000 [==============================] - 8s 211us/step - loss: 1.3993 - acc: 0.4932 - val_loss: 1.4429 - val_acc: 0.5420
# Epoch 3/10
# 40000/40000 [==============================] - 8s 211us/step - loss: 1.2561 - acc: 0.5504 - val_loss: 1.3129 - val_acc: 0.5828
# Epoch 4/10
# 40000/40000 [==============================] - 8s 212us/step - loss: 1.1730 - acc: 0.5825 - val_loss: 1.2221 - val_acc: 0.6137
# Epoch 5/10
# 40000/40000 [==============================] - 9s 213us/step - loss: 1.1029 - acc: 0.6083 - val_loss: 1.1460 - val_acc: 0.6482
# Epoch 6/10
# 40000/40000 [==============================] - 8s 212us/step - loss: 1.0512 - acc: 0.6290 - val_loss: 1.1511 - val_acc: 0.6388
# Epoch 7/10
# 40000/40000 [==============================] - 8s 211us/step - loss: 1.0015 - acc: 0.6462 - val_loss: 1.0877 - val_acc: 0.6423
# Epoch 8/10
# 40000/40000 [==============================] - 9s 213us/step - loss: 0.9741 - acc: 0.6558 - val_loss: 1.0221 - val_acc: 0.6729
# Epoch 9/10
# 40000/40000 [==============================] - 8s 212us/step - loss: 0.9407 - acc: 0.6699 - val_loss: 1.0174 - val_acc: 0.6873
# Epoch 10/10
# 40000/40000 [==============================] - 9s 213us/step - loss: 0.9063 - acc: 0.6835 - val_loss: 0.9631 - val_acc: 0.7004

# %%
score = model.evaluate(x_test, y_test)
print(score)

plt.plot(history.history['acc'],label='acc')
plt.plot(history.history['val_acc'], label='val_acc')
plt.legend(loc=2)
plt.show()
plt.plot(history.history['loss'],label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend(loc=2)
plt.show()
# Out:
# 10000/10000 [==============================] - 1s 133us/step
# [0.9636586875915527, 0.7032]

# %%
data_generator = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True)

model = Sequential()
model.add(Conv2D(64, (3, 3),  input_shape=x_train.shape[1:], padding='same', activation='relu'))
model.add(Dropout(0.25))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(32, (3, 3), padding='same', activation='relu'))
model.add(Dropout(0.25))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3), padding='same', activation='relu'))
model.add(Dropout(0.25))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))
model.summary()

model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy'])

history = model.fit_generator(data_generator.flow(x_train, y_train, batch_size=batch_size),
                    steps_per_epoch=int(len(x_train)/batch_size), 
                    epochs=epochs,
                    validation_data=(x_test, y_test),
                    verbose=1,)
score = model.evaluate(x_test, y_test)
print(score)

plt.plot(history.history['acc'],label='acc')
plt.plot(history.history['val_acc'], label='val_acc')
plt.legend(loc=2)
plt.show()
plt.plot(history.history['loss'],label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend(loc=2)
plt.show()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_16 (Conv2D)           (None, 32, 32, 64)        1792
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 32, 32, 64)        0
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 16, 16, 32)        18464
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 16, 16, 32)        0
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 8, 8, 32)          9248
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 8, 8, 32)          0
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 4, 4, 32)          0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 10)                2570
# =================================================================
# Total params: 163,402
# Trainable params: 163,402
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 390/390 [==============================] - 33s 86ms/step - loss: 1.8628 - acc: 0.3058 - val_loss: 1.6667 - val_acc: 0.4329
# Epoch 2/10
# 390/390 [==============================] - 32s 83ms/step - loss: 1.5804 - acc: 0.4213 - val_loss: 1.5272 - val_acc: 0.4978
# Epoch 3/10
# 390/390 [==============================] - 32s 81ms/step - loss: 1.4776 - acc: 0.4638 - val_loss: 1.3526 - val_acc: 0.5592
# Epoch 4/10
# 390/390 [==============================] - 32s 81ms/step - loss: 1.4098 - acc: 0.4897 - val_loss: 1.3013 - val_acc: 0.5607
# Epoch 5/10
# 390/390 [==============================] - 31s 80ms/step - loss: 1.3572 - acc: 0.5108 - val_loss: 1.2331 - val_acc: 0.5971
# Epoch 6/10
# 390/390 [==============================] - 31s 80ms/step - loss: 1.3229 - acc: 0.5262 - val_loss: 1.1957 - val_acc: 0.6055
# Epoch 7/10
# 390/390 [==============================] - 31s 80ms/step - loss: 1.2928 - acc: 0.5359 - val_loss: 1.2018 - val_acc: 0.5889
# Epoch 8/10
# 390/390 [==============================] - 31s 80ms/step - loss: 1.2693 - acc: 0.5435 - val_loss: 1.1246 - val_acc: 0.6260
# Epoch 9/10
# 390/390 [==============================] - 31s 79ms/step - loss: 1.2517 - acc: 0.5508 - val_loss: 1.1277 - val_acc: 0.6166
# Epoch 10/10
# 390/390 [==============================] - 31s 80ms/step - loss: 1.2259 - acc: 0.5628 - val_loss: 1.1126 - val_acc: 0.6247
# 10000/10000 [==============================] - 1s 131us/step
# [1.1126140233993531, 0.6247]

# %%
data_generator = ImageDataGenerator(
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1)

model = Sequential()
model.add(Conv2D(64, (3, 3),  input_shape=x_train.shape[1:], padding='same', activation='relu'))
model.add(Dropout(0.25))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(32, (3, 3), padding='same', activation='relu'))
model.add(Dropout(0.25))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3), padding='same', activation='relu'))
model.add(Dropout(0.25))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))
model.summary()

model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy'])

history = model.fit_generator(data_generator.flow(x_train, y_train, batch_size=batch_size),
                    steps_per_epoch=int(len(x_train)/batch_size), 
                    epochs=epochs,
                    validation_data=(x_test, y_test),
                    verbose=1,)
score = model.evaluate(x_test, y_test)
print(score)

plt.plot(history.history['acc'],label='acc')
plt.plot(history.history['val_acc'], label='val_acc')
plt.legend(loc=2)
plt.show()
plt.plot(history.history['loss'],label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend(loc=2)
plt.show()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_19 (Conv2D)           (None, 32, 32, 64)        1792
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 32, 32, 64)        0
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 16, 16, 32)        18464
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 16, 16, 32)        0
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 8, 8, 32)          9248
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 8, 8, 32)          0
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 4, 4, 32)          0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dropout_26 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 10)                2570
# =================================================================
# Total params: 163,402
# Trainable params: 163,402
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 390/390 [==============================] - 32s 82ms/step - loss: 1.7690 - acc: 0.3487 - val_loss: 1.5773 - val_acc: 0.4804
# Epoch 2/10
# 390/390 [==============================] - 31s 80ms/step - loss: 1.4436 - acc: 0.4789 - val_loss: 1.3691 - val_acc: 0.5453
# Epoch 3/10
# 390/390 [==============================] - 31s 80ms/step - loss: 1.3215 - acc: 0.5239 - val_loss: 1.2784 - val_acc: 0.5890
# Epoch 4/10
# 390/390 [==============================] - 31s 81ms/step - loss: 1.2409 - acc: 0.5549 - val_loss: 1.1806 - val_acc: 0.6137
# Epoch 5/10
# 390/390 [==============================] - 31s 80ms/step - loss: 1.1865 - acc: 0.5777 - val_loss: 1.1561 - val_acc: 0.6091
# Epoch 6/10
# 390/390 [==============================] - 31s 80ms/step - loss: 1.1488 - acc: 0.5920 - val_loss: 1.1070 - val_acc: 0.6342
# Epoch 7/10
# 390/390 [==============================] - 31s 79ms/step - loss: 1.1057 - acc: 0.6039 - val_loss: 1.0400 - val_acc: 0.6731
# Epoch 8/10
# 390/390 [==============================] - 31s 79ms/step - loss: 1.0842 - acc: 0.6147 - val_loss: 1.0498 - val_acc: 0.6439
# Epoch 9/10
# 390/390 [==============================] - 30s 78ms/step - loss: 1.0517 - acc: 0.6270 - val_loss: 0.9965 - val_acc: 0.6557
# Epoch 10/10
# 390/390 [==============================] - 30s 78ms/step - loss: 1.0295 - acc: 0.6341 - val_loss: 0.9369 - val_acc: 0.6850
# 10000/10000 [==============================] - 1s 127us/step
# [0.9369044870376587, 0.685]

# %% [markdown]
# ## 利用範例的 augmentation 設定，可能有點晃太大，十個 epochs 沒能觀察出甚麼...
# ## 我們把範例的 augmentation 設定減少一倍效果，可以看到十個 epochs 時 loss 相當於不加 augmentation 時還低，雖然 accuracy 還沒有呈現好。
#
# ## 後續:
# 1. 將 epochs 拉到 50 看看 (去逼出 overfitting?)
# 2. 這個模型會不會有點弱，可以加層加參數來看看，甚至應該在 underfitting 時不要用 dropout 才是。
